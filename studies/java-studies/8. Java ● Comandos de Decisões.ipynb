# %% [markdown]
# ## @yullano90 | Java ● Comandos de Decisões

# %%
Instituto Federal de Ciência e Tecnologia do Maranhão @IFMA
Departamento de Computação
Sistemas de Informação
Linguagem de Programação II Java
Prof. MSc: Jose Flavio Gomes Barros
-----------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
-----------------------------------------------------------------------------

        System.out.println("\n\n=========== Questão 01 ===========");
        int num = 13;
        if (num % 2 == 0) {
            System.out.println("Esse número é par");
        } else {
            System.out.println("Esse número é ìmpar");
        }
        
        //OU:
        
        System.out.println("\n\n=========== Questão 01 ===========");        
        int num = 13;
        System.out.println("Esse número é " + ((num % 2 == 0)? "par":"impar"));
        
        

        System.out.println("\n\n=========== Questão 02 ===========");
        System.out.println("Informe um número");
        Scanner numeroQ2 = new Scanner(System.in);
        int numero = numeroQ2.nextInt();
        int result = numero * 2;
        if (result > 30) {
            System.out.println("Resultado = " + result);
        }
        
-----------------------------------------------------------------------------

# %%
-----------------------------------------------------------------------------

        System.out.println("\n\n=========== Questão 03 ===========");
        System.out.println("Informe dois números");
        Scanner numeroQ3 = new Scanner(System.in);
        int n1 = numeroQ3.nextInt();
        int n2 = numeroQ3.nextInt(); 
        if (n1 != n2) {
            System.out.println(
                    n1*n1 + " - " + n2*n2
            );
        } else {
            System.out.println(
                    n1*n1*n1 + " - " + n2*n2*n2
            );
        }

-----------------------------------------------------------------------------

# %%
-----------------------------------------------------------------------------

        System.out.println("\n\n=========== Questão 04 ===========");
        int idade = 13;
        String classe = "";

        if (idade >= 5 && idade <= 7) {
            classe = "Infantil A";
        } else if (idade >= 8 && idade <= 10) {
            classe = "Infantil B";
        } else if (idade >= 11 && idade <= 13) {
            classe = "Juvenil A";
        } else if (idade >= 14 && idade <= 17) {
            classe = "Juvenil B";
        }

        switch (classe) {
            case "Infantil A":
                System.out.println(classe);
                break;
            case "Infantil B":
                System.out.println(classe);
                break;
            case "Juvenil A":
                System.out.println(classe);
                break;
            case "Juvenil B":
                System.out.println(classe);
                break;
            default:
                System.out.println("Não pertence a nenhuma categoria");
        }

-----------------------------------------------------------------------------

# %%
-----------------------------------------------------------------------------

    System.out.println("\n\n=========== Questão 05 ===========");
    System.out.println("Informe o numero do mês:");
    Scanner questao5 = new Scanner(System.in);
    int mes = questao5.nextInt();

    switch (mes) {
        case 1 -> System.out.println("Janeiro");
        case 2 -> System.out.println("Fevereiro");
        case 3 -> System.out.println("Março");
        case 4 -> System.out.println("Abril");
        case 5 -> System.out.println("Maio");
        case 6 -> System.out.println("junho");
        case 7 -> System.out.println("Julho");
        case 8 -> System.out.println("Agosto");
        case 9 -> System.out.println("Setembro");
        case 10 -> System.out.println("Outubro ");
        case 11 -> System.out.println("Novembro");
        case 12 -> System.out.println("Dezembro");
        default -> System.out.println("Mes inexistente");
    }

-----------------------------------------------------------------------------

# %%
-----------------------------------------------------------------------------

        System.out.println("\n\n=========== Questão 06 ===========");
        float importancia = (float) 780000.00;
        float g1 = (float) (importancia * 0.46);
        float g2 = (float) (importancia * 0.32);
        float g3 = importancia - (g1 + g2);
        float montante = g1 + g2 + g3;
        System.out.println(
                  "\nGanhador 1 = " + g1
                + "\nGanhador 2 = " + g2
                + "\nGanhador 3 = " + g3
                + "\nMontante = " + montante
          );

-----------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
-----------------------------------------------------------------------------

        System.out.println("\n\n=========== Questão 07 ===========");
        int cod_status;
        do {
            System.out.println("Digite sua senha");
            Scanner questao7 = new Scanner(System.in);
            String senha = questao7.nextLine();
            if ("123ab".equals(senha)) {
                cod_status = 1;
            } else if (senha.length() == 5 && !"123ab".equals(senha)) {
                cod_status = 2;
            } else {
                cod_status = 3;
            }

            switch (cod_status) {
                case 1:
                    System.out.println("Senha Válida! \nPrograma encerrado");
                    break;
                case 2:
                    System.out.println("Senha com 05 caracteres, porém Inválida, \ntente novamente!");
                    break;
                default:
                    System.out.println("A senha precisa ter 05 caracteres, \ntente novamente!");
                    break;
            }

        } while (cod_status == 2 || cod_status == 3);
        
-----------------------------------------------------------------------------

# %%
-----------------------------------------------------------------------------

        System.out.println("\n\n=========== Questão 08 ===========");
        System.out.println("Informe seu peso e altura");
        Scanner questao8 = new Scanner(System.in);
        float massa = questao8.nextFloat();
        float altura = questao8.nextFloat();
        float imc = (massa /(altura * altura));
        int faixaDeRisco = 0;
        
        if (imc < 20) {
            faixaDeRisco = 1;
        } else if (imc >= 20 && imc <= 25) {
            faixaDeRisco = 2;
        } else if (imc > 25 && imc <= 30) {
            faixaDeRisco = 3;
        } else if (imc > 30 && imc <= 35) {
            faixaDeRisco = 4;
        }

        switch (faixaDeRisco) {
            case 1:
                System.out.println("Abaixo do Peso");
                break;
            case 2:
                System.out.println("Normal");
                break;
            case 3:
                System.out.println("Excesso de Peso");
                break;
            case 4:
                System.out.println("Obesidade");
                break;
            default:
                System.out.println("Obesidade Mórbida");
        } 
        
-----------------------------------------------------------------------------

# %%
-----------------------------------------------------------------------------

        System.out.println("\n\n=========== Questão 09 ===========");
        System.out.println("Informe um número:");
        Scanner questao9 = new Scanner(System.in);
        int num = questao9.nextInt();
        boolean div3 = false;
        boolean div5 = false;
        if (num % 3 == 0) {
            div3 = true;
        }
        if ((num % 5 == 0)) {
            div5 = true;
        }
        if (div3 == true && div5 == true) {
            System.out.println("Divisível por 3 e 5");
        } else if (div3 == true && div5 == false) {
            System.out.println("Divisível apenas por 3");
        } else if (div3 == false && div5 == true) {
            System.out.println("Divisível apenas por 5");
        } else {
            System.out.println("Não divisível por 3 e 5");
        }
        
-----------------------------------------------------------------------------
