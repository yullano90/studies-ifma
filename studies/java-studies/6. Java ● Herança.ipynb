# %% [markdown]
# ## @yullano90 | Herança

# %%
Instituto Federal de Ciência e Tecnologia do Maranhão @IFMA
Departamento de Computação
Sistemas de Informação
Linguagem de Programação II Java
Prof. MSc: Jose Flavio Gomes Barros
-----------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
-------------------------------------------------------------------------------

package atvHeranca;

public class Funcionario {

    //Atributos do funcionário:
    private String nome;
    private float salario;

    public void recebeSalario() {

    }

    public String getNome() {
        return nome;
    }

    public void setNome(String nome) {
        this.nome = nome;
    }

    public float getSalario() {
        return salario;
    }

    public void setSalario(float salario) {
        this.salario = salario;
    }

    @Override
    public String toString() {
        return "Funcionario{" + "nome=" + nome + ", salario=" + salario + '}';
    }

}

-------------------------------------------------------------------------------

# %%
-------------------------------------------------------------------------------

package atvHeranca;

public class Professor extends Funcionario {

    //Atributos do Professor:
    private String nome;
    private float salario = 3500;
    private float horasAula = 20;

    public void recebeExtra() {

    }

    @Override
    public String getNome() {
        return nome;
    }

    @Override
    public void setNome(String nome) {
        this.nome = nome;
    }

    @Override
    public float getSalario() {
        return salario;
    }

    @Override
    public void setSalario(float salario) {
        this.salario = salario;
    }

    public float gethorasAula() {
        return horasAula;
    }

    public void sethorasAula(float bonusHoraAula) {
        this.horasAula = horasAula;
    }

}

-------------------------------------------------------------------------------

# %%
-------------------------------------------------------------------------------

package atvHeranca;

//Programa que controla gastos de funcionários e professores.
public class Teste {

    public static void main(String[] args) {

        Funcionario func = new Funcionario();
        Professor prof = new Professor();

        //Funcionário:
        func.setNome("Pedro");
        func.setSalario(800);
        System.out.println(func.toString());

        //Professor:
        prof.setNome("José");
        prof.setSalario(1000);
        prof.sethorasAula(20);
        float bonus = 20;
        float salarioTotal = prof.getSalario() + (bonus * prof.gethorasAula());
        System.out.println(
                "\nNome: " + prof.getNome()
                + "\nSalário: " + prof.getSalario()
                + "\nHoras de Aula: " + prof.gethorasAula()
                + "\nSalário Total: " + salarioTotal
        );
    }

}

-------------------------------------------------------------------------------

# %%
-------------------------------------------------------------------------------
#Refatorando a main podemos obter algo mais simples, conforme abaixo:

package atvHeranca;
public class Teste{

    public static void main(String[] args) {
        Funcionario func = new Funcionario("Pedro", 800.0f);
        System.out.println(func);
        
        Professor prof = new Professor("Jose", 1000.0f, 20);
        System.out.println(prof);
    }
    
}

-------------------------------------------------------------------------------
