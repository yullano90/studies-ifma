# %%
Instituto Federal de Ciência e Tecnologia do Maranhão @IFMA
Departamento de Computação
Sistemas de Informação
Introdução a Computação Móvel
Prof. MSc: Jose Flavio Gomes Barros

-------------------------------------------------------------------------

A Essência da Computação Pervasiva no Meio Ambiente Integrado com Usuários Humanos.

# %% [markdown]
# ## 03 Atividade - Mapa Mental_Leituras Complementares (parte II)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 01) Mapa Mental
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 02)
#
# Telefones moveis de 2,4 e 5,0 GHz, transmissores de vídeo sem fio,
# Alto falantes sem fio, babás eletrônicas, etc.
#
#
# ---------------------------------------------------------------------------------------------------------
#
# ### 03)
# As barreiras sem fios são equipamentos que por estarem na mesma frequência ou por criar campos eletromagnéticos acabam que se tornam obstáculos para os sinais sem fio e interrompendo o processo, a exemplo disso temos: Telefones sem fio de  2,4 ou 5 GHz: esses telefones que operam na  mesma frequência dos aparelhos sem fio causam interferência no sinal,  micro ondas que geram campos de ondas, Espelho d'água: rios e lagoas refletem muito o sinal.
#
#
# ---------------------------------------------------------------------------------------------------------
#
# ### 04)
# Pois existe uma maior facilidade de acesso à internet, tornando-se um objeto capaz de alcançar um maior número de usuários. Ataques que podem ocorrer com esses dispositivos são os roubos e divulgação de dados pessoas, o uso de fake News, além do hackeamento de dispositivos.
#
# ---------------------------------------------------------------------------------------------------------
